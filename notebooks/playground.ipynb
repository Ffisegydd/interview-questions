# %%
import sys
from pathlib import Path
sys.path.append(str((Path("__file__").resolve() / ".." / ".." / "src").resolve()))

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
sys.path
# Out:
# ['/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python313.zip',
#  '/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13',
#  '/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload',
#  '',
#  '/Users/keiron/dev/interview-questions/haystack-project/.venv/lib/python3.13/site-packages',
#  '/Users/keiron/dev/interview-questions/haystack-project/src']

# %%
from question_generation import question_generation_pipeline
# Out:
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/keiron/dev/interview-questions/haystack-project/.venv/lib/python3.13/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/keiron/dev/interview-questions/haystack-project/.venv/lib/python3.13/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/keiron/dev/interview-questions/haystack-project/.venv/lib/python3.13/site-packages/certifi/cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/keiron/dev/interview-questions/haystack-project/.venv/lib/python3.13/site-packages/certifi/cacert.pem'

# %%
question_generation_pipeline.show()
